# %% [markdown]
# ## Matplotlib - Exercise 2: Museum visitors
#
# Tập dữ liệu **Museum_visitors.csv** chứa thông tin về tổng số lượng khách tham quan mỗi tháng từ 1/2014 đến 12/2019 các bảo tàng tại Los Angeles, California, Mỹ; bao gồm:
# 1.	**Avila Adobe**: là ngôi nhà cổ nhất thành phố Los Angeles, xây dựng vào năm 1818. Nó giới thiệu về lịch sử và văn hóa của thành phố qua các triển lãm và sự kiện.
# 2.	**Firehouse Museum**:  tập trung vào lịch sử và phương tiện cứu hỏa. Bảo tàng trưng bày các xe cứu thương cổ điển và thiết bị cứu hỏa, cung cấp cái nhìn sâu sắc về cuộc sống của các lính cứu hỏa.
# 3.	**Chinese American Museum**: tập trung vào việc bảo tồn và truyền đạt lịch sử, nghệ thuật và văn hóa của cộng đồng người Mỹ gốc Trung Quốc. Bảo tàng này mang đến cái nhìn đa chiều về sự đóng góp và trải nghiệm của cộng đồng này trong lịch sử của Los Angeles và Hoa Kỳ.
# 4.	**America Tropical Interpretive Center**: nơi bảo tồn tác phẩm nghệ thuật tường của nghệ sĩ Diego Rivera, được biết đến với tên gọi "America Tropical." Bức tranh này tập trung vào chủ đề lịch sử và chính trị và đã trở thành biểu tượng nghệ thuật chính trị tại Los Angeles.
#
# #### Dựa trên tập tin _Museum_visitors.csv_ , hãy thực hiện các yêu cầu sau:
# ### Câu 1:
# a) Đọc dữ liệu từ tập tin museum_visitors.csv và lưu vào biến museum.
# Hiển thị 5 dòng dữ liệu đầu, 5 dòng cuối của museum
# b) Xem thông tin info, describe
# ### Câu 2:
# Chuyển cột Month sang kiểu datetime, tạo cột month (tháng - kiểu số) và year (năm)
# ### Câu 3:
# Vẽ biểu đồ line thể hiện Lượng khách tham quan bảo tàng Avila Adobe từ năm 2014-2019
# ### Câu 4:
# Vẽ biểu đồ line thể hiện Số lượng khách tham quan các bảo tàng
# ### Câu 5:
# Vẽ biểu đồ line lượng du khách tham quan Bảo tàng Avila Adobe và America Tropical Interpretive Center trung bình theo tháng
# ### Câu 6:
# Vẽ biểu đồ line Tổng lượng du khách tham quan các Bảo tàng theo năm
# ### Câu 7:
# Vẽ biểu đồ barh thể hiện trung bình lượng du khách tham quan các bảo tàng mỗi năm
# ### Câu 8
# a) Vẽ biểu đồ histogram thể hiện Phân phối số khách tham quan bảo tàng Avila Adobe
# b) Vẽ biểu đồ histogram thể hiện Phân phối số khách tham quan bảo tàng Chinese American Museum

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Câu 1: 
# a) Đọc dữ liệu từ tập tin Museum_visitors.csv và lưu vào biến museum.  
museum = pd.read_csv('Museum_Visitors.csv', delimiter = ',')
# Hiển thị 5 dòng dữ liệu đầu của museum
museum.head()
# Out:
#     Month  America Tropical Interpretive Center  Avila Adobe  \
# 0  14-Jan                                  6602        24778
# 1  14-Feb                                  5029        18976
# 2  14-Mar                                  8129        25231
# 3  14-Apr                                  2824        26989
# 4  14-May                                 10694        36883
#
#    Chinese American Museum  Firehouse Museum
# 0                     1581              4486
# 1                     1785              4172
# 2                     3229              7082
# 3                     2129              6756
# 4                     3676             10858

# %%
# Hiển thị 5 dòng dữ liệu cuối của museum
museum.tail()
# Out:
#      Month  America Tropical Interpretive Center  Avila Adobe  \
# 67  19-Aug                                  3410        20921
# 68  19-Sep                                  3229        17689
# 69  19-Oct                                  4200        18822
# 70  19-Nov                                  4362        15507
# 71  19-Dec                                  2702        15398
#
#     Chinese American Museum  Firehouse Museum
# 67                     2017              4460
# 68                     1458              4293
# 69                     1987              4035
# 70                     2808              4385
# 71                     2388              3566

# %%
# b) Xem thông tin info, describe

# %%
museum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 5 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Month                                 72 non-null     object
#  1   America Tropical Interpretive Center  72 non-null     int64
#  2   Avila Adobe                           72 non-null     int64
#  3   Chinese American Museum               72 non-null     int64
#  4   Firehouse Museum                      72 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 2.9+ KB

# %%
museum.describe()
# Out:
#        America Tropical Interpretive Center   Avila Adobe  \
# count                             72.000000     72.000000
# mean                            6549.430556  23040.083333
# std                             2633.948960   6051.586696
# min                             2702.000000  10737.000000
# 25%                             4639.250000  18814.500000
# 50%                             6237.500000  21795.000000
# 75%                             7279.500000  26198.250000
# max                            13490.000000  41242.000000
#
#        Chinese American Museum  Firehouse Museum
# count                72.000000         72.000000
# mean               2707.958333       6125.930556
# std                1110.871520       6813.331251
# min                1073.000000       2900.000000
# 25%                2127.000000       4283.000000
# 50%                2412.000000       4864.000000
# 75%                2940.750000       5841.000000
# ...

# %%
# Câu 2: chuyển cột Month sang kiểu datetime, tạo cột month (tháng - kiểu số) và year (năm)
museum['Month'] = pd.to_datetime(museum['Month'], format='%y-%b')
museum['month'] = museum['Month'].dt.month
museum['year'] = museum['Month'].dt.year
museum
# Out:
#         Month  America Tropical Interpretive Center  Avila Adobe  \
# 0  2014-01-01                                  6602        24778
# 1  2014-02-01                                  5029        18976
# 2  2014-03-01                                  8129        25231
# 3  2014-04-01                                  2824        26989
# 4  2014-05-01                                 10694        36883
# ..        ...                                   ...          ...
# 67 2019-08-01                                  3410        20921
# 68 2019-09-01                                  3229        17689
# 69 2019-10-01                                  4200        18822
# 70 2019-11-01                                  4362        15507
# 71 2019-12-01                                  2702        15398
#
#     Chinese American Museum  Firehouse Museum  month  year
# 0                      1581              4486      1  2014
# 1                      1785              4172      2  2014
# ...

# %%
# Lưu ý sau khi chuyển sang datetime, cột Month hiển thị dạng %Y-%m-%d nhưng cần hiểu đây là dữ liệu theo tháng
# tức là tổng số khách tham quan trong 1 tháng; không phải trong 1 ngày

# %%
# Câu 3: Vẽ biểu đồ line thể hiện Lượng khách tham quan bảo tàng Avila Adobe từ năm 2014-2019
yearly_visitors = museum.groupby('year')['Avila Adobe'].sum().reset_index()
plt.figure(figsize=(10, 6))
plt.plot(yearly_visitors['year'], yearly_visitors['Avila Adobe'], marker='o', linestyle='-', color='navy')

plt.title('Tổng lượng khách tham quan bảo tàng Avila Adobe từ 2014–2019')
plt.xlabel('Năm')
plt.ylabel('Số lượng khách')
plt.grid(True)
plt.xticks(yearly_visitors['year'])
plt.tight_layout()
plt.show()

# %%
# Câu 4: Vẽ biểu đồ line thể hiện Số lượng khách tham quan các bảo tàng
# Đặt kích thước biểu đồ
plt.figure(figsize = (12,6))

# Vẽ biểu đồ line cho từng bảo tàng và đặt nhãn
plt.plot(museum['Month'], museum['America Tropical Interpretive Center'], label = 'America Tropical Interpretive Center')
plt.plot(museum['Month'], museum['Avila Adobe'], label = 'Avila Adobe')
plt.plot(museum['Month'], museum['Chinese American Museum'], label = 'Chinese American Museum')
plt.plot(museum['Month'], museum['Firehouse Museum'], label = 'Firehouse Museum')
# Đặt tiêu đề và nhãn
plt.title('Số lượng khách tham quan các bảo tàng')
plt.xlabel('Thời gian')
plt.ylabel('Số lượng khách')
# Hiển thị legend, lưới
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
# Hiển thị biểu đồ
plt.show()

# %%
# Câu 5: # Vẽ biểu đồ lượng du khách tham quan Bảo tàng Avila Adobe và America Tropical Interpretive Center trung bình theo tháng
avg_monthly = museum.groupby('month')[['Avila Adobe','America Tropical Interpretive Center']].mean().reset_index()
plt.figure(figsize = (12,6))
plt.plot(avg_monthly['month'], avg_monthly['America Tropical Interpretive Center'], label = 'America Tropical Interpretive Center')
plt.plot(avg_monthly['month'], avg_monthly['Avila Adobe'], label = 'Avila Adobe')
plt.title('Lượng du khách trung bình theo tháng (Avila Adobe & America Tropical)')
plt.xlabel('Tháng')
plt.ylabel('Số lượng khách trung bình')
plt.xticks(range(1, 13))
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Câu 6: Vẽ biểu đồ Tổng lượng du khách tham quan các Bảo tàng theo năm
avg_yearly = museum.groupby('year')[['Avila Adobe','America Tropical Interpretive Center','Chinese American Museum','Firehouse Museum']].sum().reset_index()
avg_yearly
plt.figure(figsize = (12,6))
plt.plot(avg_yearly['year'], avg_yearly['America Tropical Interpretive Center'], label = 'America Tropical Interpretive Center')
plt.plot(avg_yearly['year'], avg_yearly['Avila Adobe'], label = 'Avila Adobe')
plt.plot(avg_yearly['year'], avg_yearly['Chinese American Museum'], label = 'Chinese American Museum')
plt.plot(avg_yearly['year'], avg_yearly['Firehouse Museum'], label = 'Firehouse Museum')
plt.title('Lượng du khách tổng từng bảo tàng theo năm')
plt.xlabel('Năm')
plt.ylabel('Số lượng khách trung bình')
plt.xticks(range(2014, 2020))
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Câu 7: Vẽ biểu đồ barh thể hiện trung bình lượng du khách tham quan các bảo tàng mỗi năm
museum_cols = ['America Tropical Interpretive Center', 'Avila Adobe', 'Chinese American Museum', 'Firehouse Museum']
yearly_avg = museum.groupby('year')[museum_cols].mean()

years = yearly_avg.index
y_pos = np.arange(len(years))
bar_height = 0.2

plt.figure(figsize=(12, 8))
for i, m in enumerate(museum_cols):
    plt.barh(y_pos + i * bar_height, yearly_avg[m], height=bar_height, label=m)

plt.yticks(y_pos + bar_height * (len(museum_cols) - 1) / 2, years)
plt.title('Trung bình lượng du khách tham quan các bảo tàng mỗi năm')
plt.xlabel('Số lượng khách trung bình')
plt.ylabel('Năm')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Câu 8a) Vẽ biểu đồ histogram thể hiện Phân phối số khách tham quan bảo tàng Avila Adobe
plt.figure(figsize=(10, 6))
plt.hist(museum['Avila Adobe'], bins=10, color='skyblue', edgecolor='black')
plt.title('Phân phối số lượng khách tham quan bảo tàng Avila Adobe')
plt.xlabel('Số lượng khách')
plt.ylabel('Tần suất xuất hiện')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# b) Vẽ biểu đồ histogram thể hiện Phân phối số khách tham quan bảo tàng Chinese American Museum
plt.figure(figsize=(10, 6))
plt.hist(museum['Chinese American Museum'], bins=10, color='skyblue', edgecolor='black')
plt.title('Phân phối số lượng khách tham quan bảo tàng Chinese American Museum')
plt.xlabel('Số lượng khách')
plt.ylabel('Tần suất xuất hiện')
plt.grid(True)
plt.tight_layout()
plt.show()
